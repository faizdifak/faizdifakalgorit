# %%
print ('Nama         : Faiz Difa Kurniawan')
print ('NPM          : 2420506022')
print ('Alamat       : Desa Sidomukti Rt 03 Rw 02 Kecamatan Adimulyo Kabupaten Kebumen')
print ('Tinggi Badan : 165')
print ('Berat Badan  : 50Kg')
# Out:
# Nama         : Faiz Difa Kurniawan
# NPM          : 2420506022
# Alamat       : Desa Sidomukti Rt 03 Rw 02 Kecamatan Adimulyo Kabupaten Kebumen
# Tinggi Badan : 165
# Berat Badan  : 50Kg

# %%
print ('\033[1m UNIVERSITAS TIDAR \033[0m')
print (' Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.')
print ()
print ('\033[1m JURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMASI \033[0m')
print (' Jurusan Elektro terdiri atas tiga program studi, antara lain:')
print ('  1. S1 Teknik Elektro \x1B[3m(Bachelor of Electrical Engineering)\x1B[0m')
print ('  2. S1 Teknologi Informasi \x1B[3m(Bachelor of Information Technology)\x1B[0m')
print ('  3. S1 Teknik Mekatronika \x1B[3m(Bachelor of Mechatronics Engineering)\x1B[0m')
# Out:
#  UNIVERSITAS TIDAR
#  Universitas Tidar merupakan Perguruan Tinggi Pemerintah atau Perguruan Tinggi yang telah ditetapkan berdasarkan Peraturan Presiden Republik Indonesia Nomor 23 Tahun 2014 pada tanggal 1 April 2014.
#
#  JURUSAN TEKNIK ELEKTRO, MEKATRONIKA DAN INFORMASI
#  Jurusan Elektro terdiri atas tiga program studi, antara lain:
#   1. S1 Teknik Elektro (Bachelor of Electrical Engineering)
#   2. S1 Teknologi Informasi (Bachelor of Information Technology)
#   3. S1 Teknik Mekatronika (Bachelor of Mechatronics Engineering)
