# %%
#week 1

# %%
umur = input ("Masukan umur Anda")
age = int(umur)

if age > 17:
    print(" boleh membuat SIM")
else :
    print("Tidak boleh membuat SIM")
# Out:
# Masukan umur Anda13
# Tidak boleh membuat SIM

# %%
#week 2

# %%
Nilai = input ("Masukan Nilai AndA")
Nilai = int(Nilai)

if Nilai >= 90:
    print("Nilai A")

elif Nilai >= 80:
    print("Nilai B+")

elif Nilai >=70:
    print("Nilai B")

elif Nilai >=60:
    print("Nilai C+")

elif Nilai >=50:
    print("Nilai C")

elif Nilai >=40:
    print("Nilai D")

else :
    print("Nilai E")
# Out:
# Masukan Nilai AndA60
# Nilai C+

# %%
#week 3

# %%
Nilai = input ("Masukan Nilai Anda ")
Nilai = int(Nilai)

if 80.00 <= Nilai <= 100:
    print("NIlai A")
elif 77.50 <= Nilai <= 79.99:
    print("Nilai A-")
elif 75.00 <= Nilai <= 76.49:
    print("Nilai A/B")
elif 72.50 <= Nilai <= 74.99:
    print("Nilai B+")
elif 70.00 <= Nilai <= 72.49:
    print("Nilai B")
elif 67.50 <= Nilai <= 69.99:
    print("Nilai B-")
elif 65.00 <= Nilai <= 67.49:
    print("Nilai B/C")
elif 62.50 <= Nilai <= 64.99:
    print("Nilai C+")
elif 60.00 <= Nilai <= 62.49:
    print("Nilai C")
elif 55.00 <= Nilai <= 59.99:
    print("Nilai C-")
elif 50.00 <= Nilai <= 54.99:
    print("Nilai C/D")
elif 45.00 <= Nilai <= 49.99:
    print("Nilai D+")
elif 40.00 <= Nilai <= 44.99:
    print("Nilai D")
else:
    if Nilai < 40.00:
        print("Nilai E")
# Out:
# Masukan Nilai Anda 53
# Nilai C/D
