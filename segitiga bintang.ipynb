# %%
print("*")
print("**")
print("***")
print("****")
print("*****")
# Out:
# *
# **
# ***
# ****
# *****

# %%
print("*****")
print("****")
print("***")
print("**")
print("*")
# Out:
# *****
# ****
# ***
# **
# *
