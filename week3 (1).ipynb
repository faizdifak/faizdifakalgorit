# %%
with open("untitled.txt", "r") as Biodata:
    print(Biodata.read())
# Out:
# Nama           : Faiz Difa Kurniawan
# NPM            : 2420506022
# Program Studi  : S1 Teknologi Informasi
# Alamat         : Desa Sidomukti 03/02 Adimulyo,Kebumen
# Email          : faizkurniawan297@gmail.com

# %%
with open("untitled.txt", "w") as Biodata2:
     Biodata2.write("Nama           : Faiz Difa Kurniawan \n")
     Biodata2.write("NPM            : 2420506022 \n")
     Biodata2.write("Program Studi  : S1 Teknologi Informasi \n")
     Biodata2.write("Alamat         : Desa Sidomukti 03/02 Adimulyo,Kebumen \n")
     Biodata2.write("Email          : faizkurniawan297@gmail.com \n")

# %%
with open('untitled.txt', 'r')as readbiodata:
  lines=readbiodata.readlines()
  Nama=lines[0].strip()
  NPM=lines[1].strip()
  Prodi=lines[2].strip()
  Alamat=lines[3].strip()

# %%
with open('untitled.txt','r')as readbiodata:
  with open('untitled2.txt', 'w')as biodata2:
    biodata2.write(f'{Nama}\n')
    biodata2.write(f'{NPM}\n')
    biodata2.write(f'{Prodi}\n')
    biodata2.write(f'{Alamat}\n')

# %%
with open('untitled2.txt', 'r')as readbiodata2:
  print(readbiodata2.read())

# %%
print("Selamat datang di Toko Maju Jaya")
print("Senin, 4 September 2023 13.05")

print("\nDAFTAR BELANJA:")
item1    = "Sabun"
item2    = "Shampo"
item3    = "MIe instan"
item4    = "Detergen"
harga1   = 10000
harga2   = 15000
harga3   = 5000
harga4   = 17500

total = harga1 + harga2 + harga3 + harga4

print(item1, "= Rp", harga1)
print(item2, "= Rp", harga2)
print(item3, "= Rp", harga3)
print(item4, "= Rp", harga4)

print("\nTotal = Rp", total)

with open('Toko.txt', 'w') as writefile:
    writefile.write("Selamat Datang di Toko Maju Jaya\n")
    writefile.write("\n")
    writefile.write("Toko - 4 September 2023\n")
    writefile.write("\n")
    writefile.write(item1 + " = Rp " + str(harga1) + "\n")
    writefile.write(item2 + " = Rp " + str(harga2) + "\n")
    writefile.write(item3 + " = Rp " + str(harga3) + "\n")
    writefile.write(item4 + " = Rp " + str(harga4) + "\n")
    writefile.write("\n")
    writefile.write("Total Belanja = Rp " + str(total))
# Out:
# Selamat datang di Toko Maju Jaya
# Senin, 4 September 2023 13.05
#
# DAFTAR BELANJA:
# Sabun = Rp 10000
# Shampo = Rp 15000
# MIe instan = Rp 5000
# Detergen = Rp 17500
#
# Total = Rp 47500

# %%
with open('Toko.txt', 'r')as readfile:
  print(readfile.read())
# Out:
# Selamat Datang di Toko Maju Jaya
#
# Toko - 4 September 2023
#
# Sabun = Rp 10000
# Shampo = Rp 15000
# MIe instan = Rp 5000
# Detergen = Rp 17500
#
# Total Belanja = Rp 47500
